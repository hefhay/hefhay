# %%
import pandas as pd

# %%
covid = pd.read_csv(r"C:\Users\Ahmed\Downloads\4. covid_19_data.csv")

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid.shape
# Out:
# (321, 6)

# %%
covid.nunique()
# Out:
# Date           1
# State        137
# Region       187
# Confirmed    282
# Deaths       142
# Recovered    195
# dtype: int64

# %%
covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as ply

# %% [markdown]
# # sns.heatmap(covid.isnull())

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %% [markdown]
# TO SHOW THE NUMBER OF CONFIRMED, DEATHS AND RECOVERED CASES IN EACH REGION

# %%
covid.groupby('Region')['Confirmed', 'Deaths', 'Recovered'].sum()
# Out:
# C:\Users\Ahmed\AppData\Local\Temp\ipykernel_19308\1216145716.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid.groupby('Region')['Confirmed', 'Deaths', 'Recovered'].sum()
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [raw]
# REMOVE ALL THE RECORDS WHERE CONFIRMED CASES IS LESS THAN 10

# %%
#TO GET CASES WHERE CONFIRMED CASES IS LESS THAN 10
covid[covid.Confirmed <10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
#to remove cases where confirmed cases are less than 10
covid = covid[~(covid.Confirmed <10)]
covid.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %% [markdown]
# TO GET THE REGION WHERE MAXIMUM NUMBER OF CASES WERE RECORDEED

# %%
covid.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# REGION WITH THE MINIMUM NUMBER OF DEATHS CASES

# %%
covid.groupby('Region').Deaths.sum().sort_values(ascending  = True).head(20)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Name: Deaths, dtype: int64

# %% [markdown]
# HOW MANY CONFORMED, DEATHS, AND RECOVERED CASES WERE REPORTED FROM INDIA

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid[covid.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# SORT THE ENTIRE DATA WRT NUMBER OF CONFIRMED CASES IN ASCENDING ORDER

# %%
covid.sort_values( by=['Confirmed'], ascending= True).head(20)
# Out:
#           Date                        State                            Region  \
# 156  4/29/2020                          NaN                          Suriname
# 70   4/29/2020                          NaN                          Holy See
# 59   4/29/2020                          NaN                            Gambia
# 318  4/29/2020                        Yukon                            Canada
# 217  4/29/2020                    Greenland                           Denmark
# 256  4/29/2020                   Montserrat                                UK
# 144  4/29/2020                          NaN                        Seychelles
# 27   4/29/2020                          NaN                           Burundi
# 306  4/29/2020     Turks and Caicos Islands                                UK
# 118  4/29/2020                          NaN                         Nicaragua
# 215  4/29/2020               Grand Princess                            Canada
# ...

# %% [markdown]
# SORT THE ENTIRE DATA FRAME WRT NUMBER OF RECOVERED CAESE IN DESCENDING ORDER

# %%
covid.sort_values(by= ['Recovered'], ascending = False)
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020       NaN           Spain     236899   24275     132929
# 61   4/29/2020       NaN         Germany     161539    6467     120400
# 76   4/29/2020       NaN            Iran      93657    5957      73791
# 80   4/29/2020       NaN           Italy     203591   27682      71252
# 229  4/29/2020     Hubei  Mainland China      68128    4512      63616
# ..         ...       ...             ...        ...     ...        ...
# 258  4/29/2020    Nevada              US       4934     230          0
# 257  4/29/2020  Nebraska              US       3851      56          0
# 255  4/29/2020   Montana              US        451      16          0
# 254  4/29/2020  Missouri              US       7660     338          0
# 274  4/29/2020      Ohio              US      17303     937          0
#
# [304 rows x 6 columns]
